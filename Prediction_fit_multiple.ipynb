# %% [markdown]
# ## Great fot thick layer!

# %%
import os

import tensorflow as tf
import numpy as np
from tensorflow import keras
import matplotlib.pyplot as plt
from keras.layers import Dropout
from tqdm import tqdm

# %%
import matplotlib.pyplot as plt

from scipy.special import erf

import refnx
from refnx.dataset import ReflectDataset, Data1D
from refnx.reflect import SLD, MaterialSLD, ReflectModel, Component
from refnx.analysis import Objective, CurveFitter, Transform, possibly_create_parameter
from refnx.analysis import Parameter, Parameters
from refnx.reflect import SLD, Slab, Structure, ReflectModel

# %matplotlib inline

# %%
def data_load(path):
    data = np.loadtxt(path)
    data_q = data[:,1]*(data[:,0]**4)
    maximum, minimum = -11.367532016485333, -30.062217245183856
    data_ex = (np.log(data_q)-minimum)/(maximum-minimum)
    data_ex = np.reshape(data_ex, (1, 256))
    return data_ex

# %%
model = tf.keras.models.load_model('DensNet_PTCDI')
# model.summary()

#normalization
norm = np.load("normalization_PTCDI.npy", allow_pickle =True)

# %%
data= data_load("interS/curve314.txt")
label = model.predict(data)
data_P = np.loadtxt("interS/curve314.txt")
labels = np.ones([1,7])
l_pilatus = np.ones([7])
for k in range(7): 
    l_pilatus[k] = label[:,k]*(norm[k,0]-norm[k,1])+norm[k,1]
prediction = l_pilatus
labels = np.append(labels, label, axis=0)
# %run -i BP_fit_multi.py
objective1 = objective
s1 = s
sN1 = sN
# Out:
# 1/1 [==============================] - 2s 2s/step
# <None>, 256 points
# 1.230568616230748: : 38it [02:26,  3.85s/it]
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# ________________________________________________________________________________
# Structure:
# solvent: None
# reverse structure: False
# contract: 0
#
# ________________________________________________________________________________
# Parameters:       ''
# <Parameter:  ' - thick'   , value=0 (fixed)  , bounds=[-inf, inf]>
# ________________________________________________________________________________
# Parameters:       ''
# <Parameter:   ' - sld'    , value=0 (fixed)  , bounds=[-inf, inf]>
# <Parameter:   ' - isld'   , value=0 (fixed)  , bounds=[-inf, inf]>
# <Parameter:  ' - rough'   , value=0 (fixed)  , bounds=[-inf, inf]>
# ...

# %%
data= data_load("interS/curve1012.txt")
label = model.predict(data)
data_P = np.loadtxt("interS/curve1012.txt")
labels = np.ones([1,7])
l_pilatus = np.ones([7])
for k in range(7): 
    l_pilatus[k] = label[:,k]*(norm[k,0]-norm[k,1])+norm[k,1]
prediction = l_pilatus
labels = np.append(labels, label, axis=0)
# %run -i BP_fit_multi.py
objective2 = objective
s2 = s
sN2 = sN
# Out:
# 1/1 [==============================] - 0s 33ms/step
# <None>, 256 points
# 1.4697472574566495: : 40it [02:35,  3.89s/it]
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# ________________________________________________________________________________
# Structure:
# solvent: None
# reverse structure: False
# contract: 0
#
# ________________________________________________________________________________
# Parameters:       ''
# <Parameter:  ' - thick'   , value=0 (fixed)  , bounds=[-inf, inf]>
# ________________________________________________________________________________
# Parameters:       ''
# <Parameter:   ' - sld'    , value=0 (fixed)  , bounds=[-inf, inf]>
# <Parameter:   ' - isld'   , value=0 (fixed)  , bounds=[-inf, inf]>
# <Parameter:  ' - rough'   , value=0 (fixed)  , bounds=[-inf, inf]>
# ...

# %%
data= data_load("interS/curve1613.txt") #12
label = model.predict(data)
data_P = np.loadtxt("interS/curve1613.txt")
labels = np.ones([1,7])
l_pilatus = np.ones([7])
for k in range(7): 
    l_pilatus[k] = label[:,k]*(norm[k,0]-norm[k,1])+norm[k,1]
prediction = l_pilatus
labels = np.append(labels, label, axis=0)
# %run -i BP_fit_multi.py
objective3 = objective
s3 = s
sN3 = sN
# Out:
# 1/1 [==============================] - 0s 33ms/step
# <None>, 256 points
# 1.7474094276482757: : 27it [01:50,  4.08s/it]
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# ________________________________________________________________________________
# Structure:
# solvent: None
# reverse structure: False
# contract: 0
#
# ________________________________________________________________________________
# Parameters:       ''
# <Parameter:  ' - thick'   , value=0 (fixed)  , bounds=[-inf, inf]>
# ________________________________________________________________________________
# Parameters:       ''
# <Parameter:   ' - sld'    , value=0 (fixed)  , bounds=[-inf, inf]>
# <Parameter:   ' - isld'   , value=0 (fixed)  , bounds=[-inf, inf]>
# <Parameter:  ' - rough'   , value=0 (fixed)  , bounds=[-inf, inf]>
# ...

# %%
data= data_load("interS/curve2212.txt") #12
label = model.predict(data)
data_P = np.loadtxt("interS/curve2212.txt")
labels = np.ones([1,7])
l_pilatus = np.ones([7])
for k in range(7): 
    l_pilatus[k] = label[:,k]*(norm[k,0]-norm[k,1])+norm[k,1]
prediction = l_pilatus
labels = np.append(labels, label, axis=0)
# %run -i BP_fit_multi.py
objective4 = objective
s4 = s
sN4 = sN
# Out:
# 1/1 [==============================] - 0s 33ms/step
# <None>, 256 points
# 2.8093821543680266: : 31it [02:09,  4.17s/it]
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# ________________________________________________________________________________
# Structure:
# solvent: None
# reverse structure: False
# contract: 0
#
# ________________________________________________________________________________
# Parameters:       ''
# <Parameter:  ' - thick'   , value=0 (fixed)  , bounds=[-inf, inf]>
# ________________________________________________________________________________
# Parameters:       ''
# <Parameter:   ' - sld'    , value=0 (fixed)  , bounds=[-inf, inf]>
# <Parameter:   ' - isld'   , value=0 (fixed)  , bounds=[-inf, inf]>
# <Parameter:  ' - rough'   , value=0 (fixed)  , bounds=[-inf, inf]>
# ...

# %%
data_P = np.loadtxt("interS/curve2516.txt")
labels = np.ones([1,7])
l_pilatus = np.ones([7])
for k in range(7): 
    l_pilatus[k] = label[:,k]*(norm[k,0]-norm[k,1])+norm[k,1]
prediction = l_pilatus
labels = np.append(labels, label, axis=0)
# %run -i BP_fit_multi.py
objective5 = objective
s5 = s
sN5 = sN
# Out:
# <None>, 256 points
# 2.3171663704302325: : 36it [02:40,  4.45s/it]
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# ________________________________________________________________________________
# Structure:
# solvent: None
# reverse structure: False
# contract: 0
#
# ________________________________________________________________________________
# Parameters:       ''
# <Parameter:  ' - thick'   , value=0 (fixed)  , bounds=[-inf, inf]>
# ________________________________________________________________________________
# Parameters:       ''
# <Parameter:   ' - sld'    , value=0 (fixed)  , bounds=[-inf, inf]>
# <Parameter:   ' - isld'   , value=0 (fixed)  , bounds=[-inf, inf]>
# <Parameter:  ' - rough'   , value=0 (fixed)  , bounds=[-inf, inf]>
# <Parameter:' - volfrac solvent', value=0 (fixed)  , bounds=[0.0, 1.0]>
# ...

# %%
data= data_load("interS/curve3512.txt")
label = model.predict(data)
data_P = np.loadtxt("interS/curve3512.txt")
labels = np.ones([1,7])
l_pilatus = np.ones([7])
for k in range(7): 
    l_pilatus[k] = label[:,k]*(norm[k,0]-norm[k,1])+norm[k,1]
prediction = l_pilatus
labels = np.append(labels, label, axis=0)
# %run -i BP_fit_multi.py
objective6 = objective
s6 = s
sN6 = sN
# Out:
# 1/1 [==============================] - 0s 40ms/step
# <None>, 256 points
# 2.1779599124087596: : 30it [02:19,  4.64s/it]
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# ________________________________________________________________________________
# Structure:
# solvent: None
# reverse structure: False
# contract: 0
#
# ________________________________________________________________________________
# Parameters:       ''
# <Parameter:  ' - thick'   , value=0 (fixed)  , bounds=[-inf, inf]>
# ________________________________________________________________________________
# Parameters:       ''
# <Parameter:   ' - sld'    , value=0 (fixed)  , bounds=[-inf, inf]>
# <Parameter:   ' - isld'   , value=0 (fixed)  , bounds=[-inf, inf]>
# <Parameter:  ' - rough'   , value=0 (fixed)  , bounds=[-inf, inf]>
# ...

# %%
data= data_load("interS/curve4513.txt") #12
label = model.predict(data)
data_P = np.loadtxt("interS/curve4513.txt")
labels = np.ones([1,7])
l_pilatus = np.ones([7])
for k in range(7): 
    l_pilatus[k] = label[:,k]*(norm[k,0]-norm[k,1])+norm[k,1]
prediction = l_pilatus
labels = np.append(labels, label, axis=0)
# %run -i BP_fit_multi.py
objective7 = objective
s7 = s
sN7 = sN
original7 = data_Origin[:,1]
model_N7 = model_N(q2)
# Out:
# 1/1 [==============================] - 0s 39ms/step
# <None>, 256 points
# 5.082217043148243: : 38it [02:39,  4.20s/it]
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# ________________________________________________________________________________
# Structure:
# solvent: None
# reverse structure: False
# contract: 0
#
# ________________________________________________________________________________
# Parameters:       ''
# <Parameter:  ' - thick'   , value=0 (fixed)  , bounds=[-inf, inf]>
# ________________________________________________________________________________
# Parameters:       ''
# <Parameter:   ' - sld'    , value=0 (fixed)  , bounds=[-inf, inf]>
# <Parameter:   ' - isld'   , value=0 (fixed)  , bounds=[-inf, inf]>
# <Parameter:  ' - rough'   , value=0 (fixed)  , bounds=[-inf, inf]>
# ...

# %%
data= data_load("interS/curve5511.txt") #12
label = model.predict(data)
data_P = np.loadtxt("interS/curve5511.txt")
labels = np.ones([1,7])
l_pilatus = np.ones([7])
for k in range(7): 
    l_pilatus[k] = label[:,k]*(norm[k,0]-norm[k,1])+norm[k,1]
prediction = l_pilatus
labels = np.append(labels, label, axis=0)
# %run -i BP_fit_multi.py
objective8 = objective
s8 = s
sN8 = sN
original8 = data_Origin[:,1]
model_N8 = model_N(q2)
# Out:
# 1/1 [==============================] - 0s 33ms/step
# <None>, 256 points
# 4.505623504589516: : 36it [02:14,  3.74s/it]
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# ________________________________________________________________________________
# Structure:
# solvent: None
# reverse structure: False
# contract: 0
#
# ________________________________________________________________________________
# Parameters:       ''
# <Parameter:  ' - thick'   , value=0 (fixed)  , bounds=[-inf, inf]>
# ________________________________________________________________________________
# Parameters:       ''
# <Parameter:   ' - sld'    , value=0 (fixed)  , bounds=[-inf, inf]>
# <Parameter:   ' - isld'   , value=0 (fixed)  , bounds=[-inf, inf]>
# <Parameter:  ' - rough'   , value=0 (fixed)  , bounds=[-inf, inf]>
# ...

# %%
q_values = objective1.data.x
rdata1 = objective1.data.y
rmodel1 = objective1.model(q_values)

rdata2 = objective2.data.y
rmodel2 = objective2.model(q_values)

rdata3 = objective3.data.y
rmodel3 = objective3.model(q_values)

rdata4 = objective4.data.y
rmodel4 = objective4.model(q_values)

rdata5 = objective5.data.y
rmodel5 = objective5.model(q_values)

rdata6 = objective6.data.y
rmodel6 = objective6.model(q_values)

rdata7 = objective7.data.y
rmodel7 = objective7.model(q_values)

rdata8 = objective8.data.y
rmodel8 = objective8.model(q_values)

plt.figure(figsize=(5, 5), dpi=100)
plt.plot(q_values, rdata1, 'b.')
plt.plot(q_values, rmodel1, 'r')
plt.plot(q_values, rdata2*1e2, 'b.')
plt.plot(q_values, rmodel2*1e2, 'r')
plt.plot(q_values, rdata3*1e4, 'b.')
plt.plot(q_values, rmodel3*1e4, 'r')
plt.plot(q_values, rdata4*1e6, 'b.')
plt.plot(q_values, rmodel4*1e6, 'r')
plt.plot(q_values, rdata5*1e8, 'b.')
plt.plot(q_values, rmodel5*1e8, 'r')
plt.plot(q_values, rdata6*1e10, 'b.')
plt.plot(q_values, rmodel6*1e10, 'r')
plt.plot(q_values, rdata7*1e12, 'b.')
plt.plot(q_values, rmodel7*1e12, 'r')
plt.plot(q_values, rdata8*1e14, 'b.')
plt.plot(q_values, rmodel8*1e14, 'r')

plt.xlabel('Q (Å⁻¹)')
plt.ylabel('Reflectivity')
plt.yscale('log')
plt.show()

# %%
z, sld1 = s1.sld_profile()
z, sld2 = s2.sld_profile()
z, sld3 = s3.sld_profile()
z, sld4 = s4.sld_profile()
z, sld5 = s5.sld_profile()
z, sld6 = s6.sld_profile()
z, sld7 = s7.sld_profile()
z, sld8 = s8.sld_profile()

z, sld1N = sN1.sld_profile()
z, sld2N = sN2.sld_profile()
z, sld3N = sN3.sld_profile()
z, sld4N = sN4.sld_profile()
z, sld5N = sN5.sld_profile()
z, sld6N = sN6.sld_profile()
z, sld7N = sN7.sld_profile()
z, sld8N = sN8.sld_profile()



labelsx = ['600', '400', '200', '0']

fig = plt.figure(figsize=(4, 4), dpi=100) 
ax = fig.add_subplot(111)
# Plot the SLD profile
ax.plot(z, sld1, 'r')
ax.plot(z, sld1N, 'b.', alpha = 0.3, markersize=2)
ax.plot(z, sld2+20, 'r')
ax.plot(z, sld2N+20, 'b.', alpha = 0.3, markersize=2)
ax.plot(z, sld3+40, 'r')
ax.plot(z, sld3N+40, 'b.', alpha = 0.3, markersize=2)
ax.plot(z, sld4+60, 'r')
ax.plot(z, sld4N+60, 'b.', alpha = 0.3, markersize=2)
ax.plot(z, sld5+80, 'r')
ax.plot(z, sld5N+80, 'b.', alpha = 0.3, markersize=2)
ax.plot(z, sld6+100, 'r')
ax.plot(z, sld6N+100, 'b.', alpha = 0.3, markersize=2)
ax.plot(z, sld7+120, 'r')
ax.plot(z, sld7N+120, 'b.', alpha = 0.3, markersize=2)
ax.plot(z, sld8+140, 'r')
ax.plot(z, sld8N+140, 'b.', alpha = 0.3, markersize=2)

ax.set_xlabel('Distance (Å)')
ax.set_ylabel('SLD ($10^{-6}$ Å⁻²)')
ax.set_xlim([500,1100])
ax.set_xticks([450, 650, 850, 1050], labelsx)
plt.show()

# %%
labelsx = ['700', '600', '400', '200', '0']

fig = plt.figure(figsize=(4, 4), dpi=100) 
ax = fig.add_subplot(111)
# Plot the SLD profile
#ax.plot(z, sld1, 'r')
#ax.plot(z, sld1N, 'b.', alpha = 0.3, markersize=2)
#ax.plot(z, sld2+20, 'r')
#ax.plot(z, sld2N+20, 'b.', alpha = 0.3, markersize=2)
ax.plot(z, sld3+0, 'b')
#ax.plot(z, sld3N+40, 'b.', alpha = 0.3, markersize=2)
#ax.plot(z, sld4+60, 'r')
#ax.plot(z, sld4N+60, 'b.', alpha = 0.3, markersize=2)
#ax.plot(z, sld5+80, 'r')
#ax.plot(z, sld5N+80, 'b.', alpha = 0.3, markersize=2)
#ax.plot(z, sld6+100, 'r-')
#ax.plot(z, sld6N+100, 'b.', alpha = 0.3, markersize=2)
ax.plot(z, sld6N+20, 'b', alpha = 1)
#ax.plot(z, sld7N+120, 'b.', alpha = 0.3, markersize=2)
ax.plot(z, sld8N+40, 'b', alpha = 1)
#ax.plot(z, sld8N+140, 'b.', alpha = 0.3, markersize=2)

ax.set_xlabel('Distance (Å)')
ax.set_ylabel('SLD ($10^{-6}$ Å⁻²)')
ax.set_xlim([500,1100])
ax.set_xticks([350, 450, 650, 850, 1050], labelsx)
